# %%
import torch
import torch.nn as nn
from torch.optim import SGD
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Machine Learning Summary
# ![image.png](attachment:9e635b3c-87a4-429c-b6f5-871e3bbcd90a.png)

# %% [markdown]
# # Previous Part
# ![image.png](attachment:d1ee0acc-91b1-47e4-bb81-aa89afddbafe.png)

# %%
x = torch.tensor([[6,2],[5,2],[1,3],[7,6]]).float()
y = torch.tensor([1,5,2,5]).float()

class MyNeuralNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.Matrix1 = nn.Linear(2,8,bias=False)
        self.Matrix2 = nn.Linear(8,1,bias=False)

    def forward(self, x):
        x = self.Matrix1(x)
        x = self.Matrix2(x)
        return x.squeeze()

f= MyNeuralNet()
opt = SGD(f.parameters(), lr=0.001)
L = nn.MSELoss()

#train model
losses = []
for _ in range(50):
    opt.zero_grad() #flush previous epoch's gradient
    loss_value = L(f(x), y) #compute loss
    loss_value.backward() #compute gradient
    opt.step() # perform iteration using gradient above
    losses.append(loss_value.item())

# %%
y
# Out:
# tensor([1., 5., 2., 5.])

# %%
f(x)
# Out:
# tensor([2.9249, 2.5975, 1.7682, 5.1734], grad_fn=<SqueezeBackward0>)

# %% [markdown]
# # This part
# ![image.png](attachment:135e2841-9c13-4a6a-8ac8-95f61968cedd.png)

# %%
x = torch.tensor([[4,6,2,-1,6,2,5], [1,6,2,-6,5,-3,5]])
x
# Out:
# tensor([[ 4,  6,  2, -1,  6,  2,  5],
#         [ 1,  6,  2, -6,  5, -3,  5]])

# %%
R = nn.ReLU()
R(x)
# Out:
# tensor([[4, 6, 2, 0, 6, 2, 5],
#         [1, 6, 2, 0, 5, 0, 5]])

# %% [markdown]
# Another Example

# %%
x = torch.linspace(-3,3,100)
y = R(x)

# %%
plt.plot(x.numpy(), y.numpy())
plt.grid()
plt.show()

# %% [markdown]
# How much better does our model do with this simple adjustment?

# %%
class MyNeuralNet2(nn.Module):
    def __init__(self):
        super().__init__()
        self.Matrix1 = nn.Linear(2,8,bias=False)
        self.Matrix2 = nn.Linear(8,1,bias=False)
        self.R = nn.ReLU()

    def forward(self, x):
        x = self.R(self.Matrix1(x))
        x = self.Matrix2(x)
        return x.squeeze()

# %% [markdown]
# Train model (let's write a function to do this, since we will be doing this a lot)

# %%
def train_model(x, y, f, n_epochs=50):
    opt = SGD(f.parameters(), lr=0.001)
    L = nn.MSELoss()

    #Train Model
    losses = []
    for _ in range(n_epochs):
        opt.zero_grad() # flush previous epoch's gradient
        loss_value = L(f(x), y) # compute loss
        loss_value.backward() # compute gradient
        opt.step() # perform iteration using gradient above
        losses.append(loss_value.item())
    return f, losses

# %%
x = torch.tensor([[6,2],[5,2],[1,3],[7,6]]).float()
y = torch.tensor([1,5,2,5]).float()
f2 = MyNeuralNet2()

#Train model
f2, losses2 = train_model(x, y, f2, n_epochs=5000)

# %% [markdown]
# Now let's look at the predictions.

# %%
y
# Out:
# tensor([1., 5., 2., 5.])

# %%
f2(x)
# Out:
# tensor([2.8118, 2.5193, 2.0108, 5.2174], grad_fn=<SqueezeBackward0>)

# %% [markdown]
# ![image.png](attachment:c8be74c2-e2e6-4ccc-940a-62b9c96360c9.png)

# %%
class MyNeuralNet3(nn.Module):
    def __init__(self):
        super().__init__()
        self.Matrix1 = nn.Linear(2,80,bias=False)
        self.Matrix2 = nn.Linear(80,1,bias=False)
        self.R = nn.ReLU()

    def forward(self, x):
        x = self.R(self.Matrix1(x))
        x = self.Matrix2(x)
        return x.squeeze()

# %% [markdown]
# Train Model

# %%
x = torch.tensor([[6,2],[5,2],[1,3],[7,6]]).float()
y = torch.tensor([1,5,2,5]).float()
f3 = MyNeuralNet3()

#Train model
f3, losses3 = train_model(x, y, f3, n_epochs=5000)

# %%
y
# Out:
# tensor([1., 5., 2., 5.])

# %%
f3(x)
# Out:
# tensor([2.1494, 3.3767, 1.8745, 5.2204], grad_fn=<SqueezeBackward0>)

# %% [markdown]
# ![image.png](attachment:7cfd8201-1534-41d4-8886-95397ea1d184.png)

# %%
class MyNeuralNet4(nn.Module):
    def __init__(self):
        super().__init__()
        self.Matrix1 = nn.Linear(2,80)
        self.Matrix2 = nn.Linear(80,1)
        self.R = nn.ReLU()

    def forward(self, x):
        x = self.R(self.Matrix1(x))
        x = self.Matrix2(x)
        return x.squeeze()

# %%
x = torch.tensor([[6,2],[5,2],[1,3],[7,6]]).float()
y = torch.tensor([1,5,2,5]).float()
f4 = MyNeuralNet4()

#Train model
f4, losses4 = train_model(x, y, f4, n_epochs=5000)

# %%
y
# Out:
# tensor([1., 5., 2., 5.])

# %%
f4(x)
# Out:
# tensor([1.6428, 4.1876, 2.0194, 5.0350], grad_fn=<SqueezeBackward0>)

# %% [markdown]
# ![image.png](attachment:8e77ddbb-4337-40ce-b945-c8a43e01be68.png)

# %%
class MyNeuralNet5(nn.Module):
    def __init__(self):
        super().__init__()
        self.Matrix1 = nn.Linear(2,80)
        self.Matrix2 = nn.Linear(80,80)
        self.Matrix3 = nn.Linear(80,1)
        self.R = nn.ReLU()

    def forward(self, x):
        x = self.R(self.Matrix1(x))
        x = self.R(self.Matrix2(x))
        x = self.Matrix3(x)
        return x.squeeze()

# %%
x = torch.tensor([[6,2],[5,2],[1,3],[7,6]]).float()
y = torch.tensor([1,5,2,5]).float()
f5 = MyNeuralNet5()

#Train model
f5, losses5 = train_model(x, y, f5, n_epochs=5000)

# %%
y
# Out:
# tensor([1., 5., 2., 5.])

# %%
f5(x)
# Out:
# tensor([0.9998, 4.9985, 1.9999, 4.9996], grad_fn=<SqueezeBackward0>)

# %% [markdown]
# Its predicting $y$ almost exactly (albeit by overfitting, no doubt, but the message here is that the model has the potential to fit to these arbitrary data points, through a sequence of linear transformations followed by slightly non-linear activation)

# %% [markdown]
# # The Sequential Neural Network
# ![image.png](attachment:98da55e8-1852-43ba-aab4-9c0297964c77.png)
